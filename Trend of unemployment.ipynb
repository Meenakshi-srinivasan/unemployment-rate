# %% [markdown]
# # Trend of unemployment

# %%
#importing packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#loading overall unemployment file
overall_df = pd.read_csv("Overall unemployment 15-24.csv")

# %%
#loading female unemployment rate file
female_df = pd.read_csv("female unemployment 15-24.csv")

# %%
#loading male unemployment rate file
male_df = pd.read_csv("male unemployment 15-24.csv")

# %%
#displaying overall_df
overall_df.head()
# Out:
#   Total 15-24 unemployment (%)  1981  1982  1983       1984  1985  1986  1987  \
# 0                    Australia   NaN   NaN   NaN        NaN   NaN  15.0  14.7
# 1                       Canada  12.7  18.1  19.1  17.200001  15.9  14.7  13.1
# 2                   Czech Rep.   NaN   NaN   NaN        NaN   NaN   NaN   NaN
# 3                      Estonia   NaN   NaN   NaN        NaN   NaN   NaN   NaN
# 4                      Finland   9.2   9.8  10.5   9.800000   9.1   9.7   8.9
#
#    1988  1989  ...       1997       1998       1999       2000       2001  \
# 0  13.2  11.0  ...  15.500000  14.500000  13.200000  12.000000  13.500000
# 1  11.4  10.9  ...  16.200001  15.100000  14.000000  12.600000  12.900000
# 2   NaN   NaN  ...   8.600000  12.400000  17.000000  16.900000  16.600000
# 3   NaN   NaN  ...        NaN        NaN        NaN  23.500000  21.700001
# 4   7.8   8.1  ...  23.299999  21.700001  20.200001  20.299999  18.799999
#
#    2002  2003       2004       2005  Unnamed: 26
# ...

# %%
#displaying female_df
female_df.head()
# Out:
#   Female 15-24 unemployment (%)  1981  1982       1983  1984  1985  1986  \
# 0                     Australia   NaN   NaN        NaN   NaN   NaN  14.8
# 1                        Canada  11.7  15.5  16.299999  15.4  14.3  13.3
# 2                    Czech Rep.   NaN   NaN        NaN   NaN   NaN   NaN
# 3                       Estonia   NaN   NaN        NaN   NaN   NaN   NaN
# 4                       Finland   9.6  10.2  10.800000  10.4   8.7   8.4
#
#    1987  1988  1989  ...  1997  1998       1999       2000       2001  \
# 0  14.8  13.4  11.7  ...  14.3  13.7  12.500000  11.200000  12.500000
# 1  11.9  10.5   9.6  ...  15.2  13.6  12.700000  11.400000  11.100000
# 2   NaN   NaN   NaN  ...  10.1  14.8  18.500000  17.400000  17.400000
# 3   NaN   NaN   NaN  ...   NaN   NaN        NaN  23.500000  27.299999
# 4   8.0   7.3   8.7  ...  25.0  24.5  22.200001  21.799999  20.100000
#
#         2002       2003       2004  2005  Unnamed: 26
# ...

# %%
#displaying male_df
male_df.head()
# Out:
#        country  1948  1949  1950  1951  1952  1953  1954  1955  1956  ...  \
# 0  Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1      Albania   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2      Algeria   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3       Angola   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4    Argentina   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#     2008  2009  2010  2011   2012  2013  2014  2015  2016  2017
# 0   4.09   NaN   NaN   NaN   2.55   NaN   NaN   NaN   NaN   NaN
# 1  26.90  26.2  29.6  24.8  32.30  33.6  42.5  39.2   NaN  34.1
# 2    NaN  19.0  18.7   NaN  24.90  21.6   NaN   NaN   NaN   NaN
# 3    NaN   NaN  17.7  33.2    NaN   NaN   NaN   NaN   NaN   NaN
# 4  16.50  18.8  16.6  16.5  15.30  17.0  16.7   NaN   NaN  19.9
#
# [5 rows x 71 columns]

# %% [markdown]
# # Wrangling overall_df

# %% [markdown]
# Checking dataframe details

# %%
#inspecting the type of objects in each attribute using info()
overall_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 27 columns):
# Total 15-24 unemployment (%)    29 non-null object
# 1981                            9 non-null float64
# 1982                            9 non-null float64
# 1983                            10 non-null float64
# 1984                            10 non-null float64
# 1985                            11 non-null float64
# 1986                            14 non-null float64
# 1987                            15 non-null float64
# 1988                            15 non-null float64
# 1989                            15 non-null float64
# 1990                            15 non-null float64
# 1991                            18 non-null float64
# 1992                            20 non-null float64
# 1993                            23 non-null float64
# 1994                            24 non-null float64
# 1995                            24 non-null float64
# ...

# %%
#describing overall_df dataframe
overall_df.describe()
# Out:
#             1981       1982       1983       1984       1985       1986  \
# count   9.000000   9.000000  10.000000  10.000000  11.000000  14.000000
# mean   11.644444  13.511111  14.910000  14.990000  14.300000  14.228571
# std     8.707053   9.819680   9.982924  11.692300  11.933734  10.574310
# min     4.000000   4.200000   4.500000   4.400000   4.800000   5.000000
# 25%     5.400000   7.300000   8.050000   6.175000   6.000000   6.150000
# 50%     9.200000   9.800000  13.450000  11.550000   9.100000  11.200000
# 75%    14.300000  18.100000  19.475000  20.950001  19.550000  18.224999
# max    31.100000  34.700001  37.500000  41.799999  43.700001  42.799999
#
#             1987       1988       1989       1990  ...       1997       1998  \
# count  15.000000  15.000000  15.000000  15.000000  ...  26.000000  27.000000
# mean   13.446667  12.733333  12.040000  11.806667  ...  15.430769  15.474074
# std     9.723820   8.991636   7.782379   6.987383  ...   7.916149   6.928847
# ...

# %%
#inspecting datatypes of overall_df
overall_df.dtypes
# Out:
# Total 15-24 unemployment (%)     object
# 1981                            float64
# 1982                            float64
# 1983                            float64
# 1984                            float64
# 1985                            float64
# 1986                            float64
# 1987                            float64
# 1988                            float64
# 1989                            float64
# 1990                            float64
# 1991                            float64
# 1992                            float64
# 1993                            float64
# 1994                            float64
# 1995                            float64
# 1996                            float64
# 1997                            float64
# 1998                            float64
# 1999                            float64
# 2000                            float64
# 2001                            float64
# 2002                            float64
# ...

# %%
overall_df.shape
# Out:
# (30, 27)

# %%
#Renaming columns
overall_df.rename(columns = {"Total 15-24 unemployment (%)":"country"},inplace=True)

# %%
#Displaying after renaming the columns
overall_df.head(2)
# Out:
#      country  1981  1982  1983       1984  1985  1986  1987  1988  1989  ...  \
# 0  Australia   NaN   NaN   NaN        NaN   NaN  15.0  14.7  13.2  11.0  ...
# 1     Canada  12.7  18.1  19.1  17.200001  15.9  14.7  13.1  11.4  10.9  ...
#
#         1997  1998  1999  2000  2001  2002  2003  2004  2005  Unnamed: 26
# 0  15.500000  14.5  13.2  12.0  13.5  12.8  12.1  11.5  10.7          NaN
# 1  16.200001  15.1  14.0  12.6  12.9  13.6  13.6  13.3  12.4          NaN
#
# [2 rows x 27 columns]

# %% [markdown]
# # Wrangling of female_df

# %%
#displaying datatypes of female_df columns
female_df.dtypes
# Out:
# Female 15-24 unemployment (%)     object
# 1981                             float64
# 1982                             float64
# 1983                             float64
# 1984                             float64
# 1985                             float64
# 1986                             float64
# 1987                             float64
# 1988                             float64
# 1989                             float64
# 1990                             float64
# 1991                             float64
# 1992                             float64
# 1993                             float64
# 1994                             float64
# 1995                             float64
# 1996                             float64
# 1997                             float64
# 1998                             float64
# 1999                             float64
# 2000                             float64
# 2001                             float64
# 2002                             float64
# ...

# %%
#displaying information of female_df
female_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 27 columns):
# Female 15-24 unemployment (%)    29 non-null object
# 1981                             9 non-null float64
# 1982                             9 non-null float64
# 1983                             10 non-null float64
# 1984                             10 non-null float64
# 1985                             11 non-null float64
# 1986                             14 non-null float64
# 1987                             15 non-null float64
# 1988                             15 non-null float64
# 1989                             15 non-null float64
# 1990                             15 non-null float64
# 1991                             18 non-null float64
# 1992                             20 non-null float64
# 1993                             23 non-null float64
# 1994                             24 non-null float64
# 1995                             24 non-null float64
# ...

# %%
#describing the columns of female_df
female_df.describe()
# Out:
#             1981       1982       1983       1984       1985       1986  \
# count   9.000000   9.000000  10.000000  10.000000  11.000000  14.000000
# mean   12.811111  14.488889  15.600000  15.800000  15.109091  14.814286
# std    10.571713  11.446992  11.788130  13.603921  14.073696  12.294080
# min     3.800000   4.100000   4.400000   4.300000   4.700000   5.100000
# 25%     6.200000   7.800000   8.550000   6.450000   6.000000   6.700000
# 50%     9.600000  10.200000  13.200000  11.800000   8.700000  10.550000
# 75%    13.900000  16.100000  17.275000  18.175000  18.150000  19.600001
# max    35.700001  39.400002  43.700001  48.099998  50.900002  49.900002
#
#             1987       1988       1989       1990  ...       1997       1998  \
# count  15.000000  15.000000  15.000000  15.000000  ...  26.000000  27.000000
# mean   14.486667  13.780000  13.206667  12.706667  ...  16.434615  16.151852
# std    11.863442  11.534495  10.380508   9.315384  ...   9.600039   8.386728
# ...

# %%
#displays top 2 rows
female_df.head(2)
# Out:
#   Female 15-24 unemployment (%)  1981  1982       1983  1984  1985  1986  \
# 0                     Australia   NaN   NaN        NaN   NaN   NaN  14.8
# 1                        Canada  11.7  15.5  16.299999  15.4  14.3  13.3
#
#    1987  1988  1989  ...  1997  1998  1999  2000  2001  2002  2003  2004  \
# 0  14.8  13.4  11.7  ...  14.3  13.7  12.5  11.2  12.5  11.9  11.5  11.1
# 1  11.9  10.5   9.6  ...  15.2  13.6  12.7  11.4  11.1  11.7  11.8  11.7
#
#    2005  Unnamed: 26
# 0  10.5          NaN
# 1  10.6          NaN
#
# [2 rows x 27 columns]

# %%
#renaming "Female 15-24 unemployment (%)" column to country
female_df.rename(columns={'Female 15-24 unemployment (%)' : 'country'},inplace=True)
female_df.head(2)
# Out:
#      country  1981  1982       1983  1984  1985  1986  1987  1988  1989  ...  \
# 0  Australia   NaN   NaN        NaN   NaN   NaN  14.8  14.8  13.4  11.7  ...
# 1     Canada  11.7  15.5  16.299999  15.4  14.3  13.3  11.9  10.5   9.6  ...
#
#    1997  1998  1999  2000  2001  2002  2003  2004  2005  Unnamed: 26
# 0  14.3  13.7  12.5  11.2  12.5  11.9  11.5  11.1  10.5          NaN
# 1  15.2  13.6  12.7  11.4  11.1  11.7  11.8  11.7  10.6          NaN
#
# [2 rows x 27 columns]

# %%
#setting country as index for female_df
female_df.set_index('country',drop=True,inplace=True)

# %%
#drop unnecessay column "Unnamed: 26"
female_df.drop('Unnamed: 26',axis=1,inplace=True)

# %%
#drop unnecessary row in the index location 29
female_df.drop(female_df.iloc[29],axis=0,inplace=True)

# %% [markdown]
# # Wrangling of male_df

# %%
#displays top 2 records from male_df
male_df.head(2)
# Out:
#        country  1948  1949  1950  1951  1952  1953  1954  1955  1956  ...  \
# 0  Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1      Albania   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#     2008  2009  2010  2011   2012  2013  2014  2015  2016  2017
# 0   4.09   NaN   NaN   NaN   2.55   NaN   NaN   NaN   NaN   NaN
# 1  26.90  26.2  29.6  24.8  32.30  33.6  42.5  39.2   NaN  34.1
#
# [2 rows x 71 columns]

# %%
#set country as index for male_df
male_df.set_index('country',drop=True,inplace=True)

# %%
#displays top 5 records from male_df
male_df.head()
# Out:
#              1948  1949  1950  1951  1952  1953  1954  1955  1956  1957  ...  \
# country                                                                  ...
# Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Albania       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Algeria       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Angola        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Argentina     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#               2008  2009  2010  2011   2012  2013  2014  2015  2016  2017
# country
# Afghanistan   4.09   NaN   NaN   NaN   2.55   NaN   NaN   NaN   NaN   NaN
# Albania      26.90  26.2  29.6  24.8  32.30  33.6  42.5  39.2   NaN  34.1
# Algeria        NaN  19.0  18.7   NaN  24.90  21.6   NaN   NaN   NaN   NaN
# Angola         NaN   NaN  17.7  33.2    NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
#filtering columns in the range 1981-2005
for x in male_df.columns:
    if(x >= str('1948') and x < str('1981')):
        male_df.drop(x,axis=1,inplace=True)
    elif(x > str('2005') and x<str('2018')):
        male_df.drop(x,axis=1,inplace=True)

# %%
#displays top 2 records from male_df
male_df.head(2)
# Out:
#              1981  1982  1983  1984  1985  1986  1987  1988  1989  1990  ...  \
# country                                                                  ...
# Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Albania       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#              1996  1997  1998  1999  2000  2001  2002  2003  2004  2005
# country
# Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [2 rows x 25 columns]

# %%
#displays shape of male_df
male_df.shape
# Out:
# (167, 25)

# %%
#dislays last 5 records in male_df
male_df.tail()
# Out:
#            1981  1982  1983  1984  1985  1986  1987  1988  1989  1990  ...  \
# country                                                                ...
# Venezuela   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Vietnam     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Yemen       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Zambia      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Zimbabwe    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#            1996  1997  1998  1999  2000  2001  2002  2003  2004  2005
# country
# Venezuela   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  16.4
# Vietnam     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  4.38   NaN
# Yemen       NaN   NaN   NaN  20.5   NaN   NaN   NaN   NaN   NaN   NaN
# Zambia      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zimbabwe    NaN  20.7   NaN  17.0   NaN   NaN   NaN   NaN  7.13   NaN
#
# ...

# %% [markdown]
# # Data cleaning for overall_df

# %%
#displaying the count of missing values in each column
overall_df.isna().any().sum()
# Out:
# 27

# %%
#dropping unnecessary column "Unnamed : 26"
overall_df.drop(columns="Unnamed: 26", inplace=True)

# %%
#display top 2 records of overall_df
overall_df.head(2)
# Out:
#      country  1981  1982  1983       1984  1985  1986  1987  1988  1989  ...  \
# 0  Australia   NaN   NaN   NaN        NaN   NaN  15.0  14.7  13.2  11.0  ...
# 1     Canada  12.7  18.1  19.1  17.200001  15.9  14.7  13.1  11.4  10.9  ...
#
#         1997  1998  1999  2000  2001  2002  2003  2004  2005  Unnamed: 26
# 0  15.500000  14.5  13.2  12.0  13.5  12.8  12.1  11.5  10.7          NaN
# 1  16.200001  15.1  14.0  12.6  12.9  13.6  13.6  13.3  12.4          NaN
#
# [2 rows x 27 columns]

# %%
#set index of overall_df as country
overall_df.set_index('country',drop=True,inplace=True)
overall_df.head(2)
# Out:
#            1981  1982  1983       1984  1985  1986  1987  1988  1989  1990  \
# country
# Australia   NaN   NaN   NaN        NaN   NaN  15.0  14.7  13.2  11.0  12.9
# Canada     12.7  18.1  19.1  17.200001  15.9  14.7  13.1  11.4  10.9  12.3
#
#            ...       1997  1998  1999  2000  2001  2002  2003  2004  2005  \
# country    ...
# Australia  ...  15.500000  14.5  13.2  12.0  13.5  12.8  12.1  11.5  10.7
# Canada     ...  16.200001  15.1  14.0  12.6  12.9  13.6  13.6  13.3  12.4
#
#            Unnamed: 26
# country
# Australia          NaN
# Canada             NaN
#
# [2 rows x 26 columns]

# %%
#filling empty records with mean value of the column
overall_df = overall_df.apply(lambda row: row.fillna(row.mean()),axis=0)
overall_df
# Out:
#                        1981       1982   1983       1984       1985  \
# country
# Australia         11.644444  13.511111  14.91  14.990000  14.300000
# Canada            12.700000  18.100000  19.10  17.200001  15.900000
# Czech Rep.        11.644444  13.511111  14.91  14.990000  14.300000
# Estonia           11.644444  13.511111  14.91  14.990000  14.300000
# Finland            9.200000   9.800000  10.50   9.800000   9.100000
# France            17.500000  18.799999  19.60  23.200001  23.200001
# Germany           11.644444  13.511111  14.91  14.990000  14.300000
# Hong Kong, China  11.644444  13.511111  14.91  14.990000   5.800000
# Ireland           11.644444  13.511111  20.10  22.200001  23.500000
# Japan              4.000000   4.300000   4.50   4.900000   4.800000
# Korea, Rep.       11.644444  13.511111  14.91  14.990000  14.300000
# Latvia            11.644444  13.511111  14.91  14.990000  14.300000
# Lithuania         11.644444  13.511111  14.91  14.990000  14.300000
# ...

# %%
#Check whether any missing value is present
overall_df.isna().any().sum()
# Out:
# 1

# %% [markdown]
# Check duplicate values

# %%
#count of duplicate values
overall_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Check datatypes

# %%
#checking datatypes of all columns
overall_df.dtypes
# Out:
# 1981           float64
# 1982           float64
# 1983           float64
# 1984           float64
# 1985           float64
# 1986           float64
# 1987           float64
# 1988           float64
# 1989           float64
# 1990           float64
# 1991           float64
# 1992           float64
# 1993           float64
# 1994           float64
# 1995           float64
# 1996           float64
# 1997           float64
# 1998           float64
# 1999           float64
# 2000           float64
# 2001           float64
# 2002           float64
# 2003           float64
# 2004           float64
# 2005           float64
# Unnamed: 26    float64
# dtype: object

# %%
#display all records from overall_df
overall_df
# Out:
#                        1981       1982   1983       1984       1985  \
# country
# Australia         11.644444  13.511111  14.91  14.990000  14.300000
# Canada            12.700000  18.100000  19.10  17.200001  15.900000
# Czech Rep.        11.644444  13.511111  14.91  14.990000  14.300000
# Estonia           11.644444  13.511111  14.91  14.990000  14.300000
# Finland            9.200000   9.800000  10.50   9.800000   9.100000
# France            17.500000  18.799999  19.60  23.200001  23.200001
# Germany           11.644444  13.511111  14.91  14.990000  14.300000
# Hong Kong, China  11.644444  13.511111  14.91  14.990000   5.800000
# Ireland           11.644444  13.511111  20.10  22.200001  23.500000
# Japan              4.000000   4.300000   4.50   4.900000   4.800000
# Korea, Rep.       11.644444  13.511111  14.91  14.990000  14.300000
# Latvia            11.644444  13.511111  14.91  14.990000  14.300000
# Lithuania         11.644444  13.511111  14.91  14.990000  14.300000
# ...

# %% [markdown]
# # Data cleaning for female_df

# %%
#check the count of null values in female_df
female_df.isna().sum()
# Out:
# 1981    20
# 1982    20
# 1983    19
# 1984    19
# 1985    18
# 1986    15
# 1987    14
# 1988    14
# 1989    14
# 1990    14
# 1991    11
# 1992     9
# 1993     6
# 1994     5
# 1995     5
# 1996     4
# 1997     3
# 1998     2
# 1999     2
# 2000     2
# 2001     0
# 2002     0
# 2003     0
# 2004     0
# 2005     2
# dtype: int64

# %%
#filling empty values with mean value of the column
female_df = female_df.apply(lambda row: row.fillna(row.mean()),axis=0)
female_df.head(1)
# Out:
#                 1981       1982  1983  1984       1985  1986  1987  1988  \
# country
# Australia  12.811111  14.488889  15.6  15.8  15.109091  14.8  14.8  13.4
#
#            1989  1990  ...  1996  1997  1998  1999  2000  2001  2002  2003  \
# country                ...
# Australia  11.7  12.7  ...  14.2  14.3  13.7  12.5  11.2  12.5  11.9  11.5
#
#            2004  2005
# country
# Australia  11.1  10.5
#
# [1 rows x 25 columns]

# %%
#checks for missing values
female_df.isna().any().sum()
# Out:
# 0

# %%
#checks for duplicate values
female_df.duplicated().sum()
# Out:
# 0

# %%
#checks datatypes
female_df.dtypes
# Out:
# 1981    float64
# 1982    float64
# 1983    float64
# 1984    float64
# 1985    float64
# 1986    float64
# 1987    float64
# 1988    float64
# 1989    float64
# 1990    float64
# 1991    float64
# 1992    float64
# 1993    float64
# 1994    float64
# 1995    float64
# 1996    float64
# 1997    float64
# 1998    float64
# 1999    float64
# 2000    float64
# 2001    float64
# 2002    float64
# 2003    float64
# 2004    float64
# 2005    float64
# dtype: object

# %%
#creating a new column to store mean value of every country
female_df['mean'] = female_df.apply(lambda x: x.mean(),axis=1)
female_df.head()
# Out:
#                  1981       1982       1983  1984       1985       1986  \
# country
# Australia   12.811111  14.488889  15.600000  15.8  15.109091  14.800000
# Canada      11.700000  15.500000  16.299999  15.4  14.300000  13.300000
# Czech Rep.  12.811111  14.488889  15.600000  15.8  15.109091  14.814286
# Estonia     12.811111  14.488889  15.600000  15.8  15.109091  14.814286
# Finland      9.600000  10.200000  10.800000  10.4   8.700000   8.400000
#
#                  1987   1988       1989       1990  ...       1997       1998  \
# country                                             ...
# Australia   14.800000  13.40  11.700000  12.700000  ...  14.300000  13.700000
# Canada      11.900000  10.50   9.600000  11.000000  ...  15.200000  13.600000
# Czech Rep.  14.486667  13.78  13.206667  12.706667  ...  10.100000  14.800000
# Estonia     14.486667  13.78  13.206667  12.706667  ...  16.434615  16.151852
# Finland      8.000000   7.30   8.700000   8.300000  ...  25.000000  24.500000
# ...

# %% [markdown]
# # Data cleaning for male_df

# %%
#displays top 5 records from male_df
male_df.head()
# Out:
#              1981  1982  1983  1984  1985  1986  1987  1988  1989  1990  ...  \
# country                                                                  ...
# Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Albania       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Algeria       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Angola        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Argentina     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#              1996  1997  1998  1999  2000  2001  2002  2003  2004  2005
# country
# Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Algeria       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Angola        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
#Filling empty values with mean values
male_df = male_df.apply(lambda row: row.fillna(row.mean()),axis=0)

# %%
#checks for the count of missing values
male_df.isna().any().sum()
# Out:
# 0

# %%
#checks datatypes of all the columns in male_df
male_df.dtypes
# Out:
# 1981    float64
# 1982    float64
# 1983    float64
# 1984    float64
# 1985    float64
# 1986    float64
# 1987    float64
# 1988    float64
# 1989    float64
# 1990    float64
# 1991    float64
# 1992    float64
# 1993    float64
# 1994    float64
# 1995    float64
# 1996    float64
# 1997    float64
# 1998    float64
# 1999    float64
# 2000    float64
# 2001    float64
# 2002    float64
# 2003    float64
# 2004    float64
# 2005    float64
# dtype: object

# %%
#creating a variable to store mean value of each country
male_mean = male_df.apply(lambda x:x.mean(),axis=1)

# %%
#creating a column to store mean value 
male_df['mean']=male_mean

# %%
male_df.head()
# Out:
#                   1981     1982       1983       1984   1985       1986  \
# country
# Afghanistan  12.685714  11.4675  16.439524  15.584737  16.58  16.402917
# Albania      12.685714  11.4675  16.439524  15.584737  16.58  16.402917
# Algeria      12.685714  11.4675  16.439524  15.584737  16.58  16.402917
# Angola       12.685714  11.4675  16.439524  15.584737  16.58  16.402917
# Argentina    12.685714  11.4675  16.439524  15.584737  16.58  16.402917
#
#                 1987     1988       1989      1990  ...       1997    1998  \
# country                                             ...
# Afghanistan  16.2552  14.6488  13.063077  13.26875  ...  15.729778  16.508
# Albania      16.2552  14.6488  13.063077  13.26875  ...  15.729778  16.508
# Algeria      16.2552  14.6488  13.063077  13.26875  ...  15.729778  16.508
# Angola       16.2552  14.6488  13.063077  13.26875  ...  15.729778  16.508
# Argentina    16.2552  14.6488  13.063077  13.26875  ...  15.729778  16.508
#
# ...

# %%
#checks the count of missing values in male_df
male_df['mean'].isna().sum()
# Out:
# 0

# %%
#displays the index of male_df
male_df.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina', 'Armenia',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas',
#        ...
#        'United Arab Emirates', 'United Kingdom', 'United States', 'Uruguay',
#        'Vanuatu', 'Venezuela', 'Vietnam', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='country', length=167)

# %% [markdown]
# # Analysis

# %% [markdown]
# Question 1 : What are the top 3 states that has most unemployed people(in percent)?

# %%
overall_df.head(2)
# Out:
#                 1981       1982   1983       1984  1985  1986  1987  1988  \
# country
# Australia  11.644444  13.511111  14.91  14.990000  14.3  15.0  14.7  13.2
# Canada     12.700000  18.100000  19.10  17.200001  15.9  14.7  13.1  11.4
#
#            1989  1990  ...       1997  1998  1999  2000  2001  2002  2003  \
# country                ...
# Australia  11.0  12.9  ...  15.500000  14.5  13.2  12.0  13.5  12.8  12.1
# Canada     10.9  12.3  ...  16.200001  15.1  14.0  12.6  12.9  13.6  13.6
#
#            2004  2005  Unnamed: 26
# country
# Australia  11.5  10.7          NaN
# Canada     13.3  12.4          NaN
#
# [2 rows x 26 columns]

# %%
#Calculation of mean value of each row
overall_mean = overall_df.apply(lambda x:x.mean(),axis=1)
overall_mean
# Out:
# country
# Australia           14.074222
# Canada              14.600000
# Czech Rep.          13.549254
# Estonia             15.543342
# Finland             17.116000
# France              21.100000
# Germany             10.872432
# Hong Kong, China     8.550222
# Ireland             16.566222
# Japan                6.368000
# Korea, Rep.         11.148654
# Latvia              17.230805
# Lithuania           17.256676
# Netherlands         10.619365
# New Zealand         12.942222
# Norway              10.068000
# Philippines         16.486222
# Poland              23.361254
# Portugal            12.892654
# Romania             16.494471
# Singapore            6.259556
# Slovak Republic     19.599889
# Slovenia            15.597254
# Spain               33.668000
# Sweden              12.160000
# Switzerland          8.888432
# Turkey              15.184432
# United Kingdom      13.706453
# United States       12.204000
# dtype: float64

# %%
#Assigning mean values to a new dataframe column
overall_df['mean']=overall_mean

# %%
#sorting values and fetching the top 3 records
top_3_states = overall_df.sort_values(by='mean',ascending=False).iloc[0:3]

# %%
#plotting countries with atmost unemployment rate
plt.figure(figsize = (8,8))
plt.pie(top_3_states['mean'],labels=top_3_states.index,colors=['#FD3A5A','#FE8296','#F9B4A2'],explode=(0.1,0.,0),shadow=True,autopct='%1.0f%%')
plt.title('Countries with atmost unemployment rate from 1981-2005 (in %)')
plt.savefig('Countries with atmost unemployment rate.png',dpi=300)

# %%
#joining top_3_states with female_df
f_top_table = top_3_states.join(female_df,lsuffix='_general',rsuffix='_female')

# %%
#displayng the dataframe after joining
f_top_table
# Out:
#          1981_general  1982_general  1983_general  1984_general  1985_general  \
# country
# Spain       31.100000     34.700001         37.50     41.799999     43.700001
# Poland      11.644444     13.511111         14.91     14.990000     14.300000
# France      17.500000     18.799999         19.60     23.200001     23.200001
#
#          1986_general  1987_general  1988_general  1989_general  1990_general  \
# country
# Spain       42.799999     40.000000     37.000000         31.90     30.100000
# Poland      14.228571     13.446667     12.733333         12.04     11.806667
# France      22.299999     21.000000     19.400000         17.50     16.600000
#
#          ...  1997_female  1998_female  1999_female  2000_female  2001_female  \
# country  ...
# Spain    ...    45.700001    42.900002    36.799999    32.799999    26.900000
# Poland   ...    28.000000    25.299999    34.799999    37.299999    42.099998
# ...

# %%
#Joining top_3_states with male_df
overall_top_table = top_3_states.join(male_df,lsuffix='_general',rsuffix='_male')
overall_top_table
# Out:
#          1981_general  1982_general  1983_general  1984_general  1985_general  \
# country
# Spain       31.100000     34.700001         37.50     41.799999     43.700001
# Poland      11.644444     13.511111         14.91     14.990000     14.300000
# France      17.500000     18.799999         19.60     23.200001     23.200001
#
#          1986_general  1987_general  1988_general  1989_general  1990_general  \
# country
# Spain       42.799999     40.000000     37.000000         31.90     30.100000
# Poland      14.228571     13.446667     12.733333         12.04     11.806667
# France      22.299999     21.000000     19.400000         17.50     16.600000
#
#          ...  1997_male  1998_male  1999_male  2000_male  2001_male  \
# country  ...
# Spain    ...       33.6       29.3       22.9       19.6       16.4
# Poland   ...       20.1       19.5       27.9       34.3       38.0
# France   ...       27.0       24.1       24.7       19.0       16.0
#
# ...

# %%
#plotting the countries with atmost unemployment rate
plt.figure(figsize=(8,5))
plt.plot(f_top_table.mean_general,marker='D',label="Overall unemployed rate")
plt.plot(f_top_table.mean_female,marker='D',label="Female unemployed rate")
plt.plot(overall_top_table.mean_male,marker='D',label="Male unemployed rate")
plt.title('Countries with atmost unemployment rate from 1980-2005 (in %)')
plt.legend()
plt.savefig('Atmost unemployment rate comparison.png',dpi=300)

# %% [markdown]
# Question : What are the top 3 states with least unemployment rate?

# %%
#Sorting the low_3_states and fetching the top 3 records
low_3_states = overall_df.sort_values(by='mean',ascending=True).iloc[0:3]

# %%
#Displaying the result of low_3_states
low_3_states
# Out:
#                        1981       1982   1983   1984  1985  1986  1987  1988  \
# country
# Singapore          4.400000   4.200000   4.80   4.40   6.2   8.0   6.2   4.6
# Japan              4.000000   4.300000   4.50   4.90   4.8   5.2   5.2   4.9
# Hong Kong, China  11.644444  13.511111  14.91  14.99   5.8   5.6   3.7   3.4
#
#                   1989  1990  ...  1998  1999       2000  2001  2002  2003  \
# country                       ...
# Singapore          3.4   3.2  ...   6.4   6.7  15.777778   6.2   7.9   8.3
# Japan              4.5   4.3  ...   7.7   9.1   9.200000   9.6   9.9  10.1
# Hong Kong, China   2.8   3.3  ...  10.3  13.2  10.600000  11.3  15.0  15.0
#
#                   2004       2005  Unnamed: 26      mean
# country
# Singapore          8.5  15.211111          NaN  6.259556
# Japan              9.5   8.700000          NaN  6.368000
# Hong Kong, China  12.2  10.800000          NaN  8.550222
#
# [3 rows x 27 columns]

# %%
#plotting the countries with least unemployment rate that shows the composition of each country
plt.figure(figsize=(10,8))
plt.pie(low_3_states['mean'],labels=low_3_states.index,explode=(0,0,0.1),colors=['cyan','green','blue'],shadow=True,autopct='%1.0f%%')
plt.title('Countries with least unemployment rate from 1981 to 2005(in %)')
plt.savefig('Countries with least unemployment rate.png',dpi=300)

# %%
#Joining low_3_states with female_df
f_low_table = low_3_states.join(female_df,lsuffix='_general',rsuffix='_female')

# %%
#Displaying the f_low_table
f_low_table
# Out:
#                   1981_general  1982_general  1983_general  1984_general  \
# country
# Singapore             4.400000      4.200000          4.80          4.40
# Japan                 4.000000      4.300000          4.50          4.90
# Hong Kong, China     11.644444     13.511111         14.91         14.99
#
#                   1985_general  1986_general  1987_general  1988_general  \
# country
# Singapore                  6.2           8.0           6.2           4.6
# Japan                      4.8           5.2           5.2           4.9
# Hong Kong, China           5.8           5.6           3.7           3.4
#
#                   1989_general  1990_general  ...  1997_female  1998_female  \
# country                                       ...
# Singapore                  3.4           3.2  ...          4.6          7.2
# Japan                      4.5           4.3  ...          6.3          7.3
# Hong Kong, China           2.8           3.3  ...          4.4          8.8
#
# ...

# %%
#Joining low_3_states and male_df to make it easier to plot
m_low_table = low_3_states.join(male_df,lsuffix='_general',rsuffix='_male')
m_low_table
# Out:
#                   1981_general  1982_general  1983_general  1984_general  \
# country
# Singapore             4.400000      4.200000          4.80          4.40
# Japan                 4.000000      4.300000          4.50          4.90
# Hong Kong, China     11.644444     13.511111         14.91         14.99
#
#                   1985_general  1986_general  1987_general  1988_general  \
# country
# Singapore                  6.2           8.0           6.2           4.6
# Japan                      4.8           5.2           5.2           4.9
# Hong Kong, China           5.8           5.6           3.7           3.4
#
#                   1989_general  1990_general  ...  1997_male  1998_male  \
# country                                       ...
# Singapore                  3.4           3.2  ...       4.45        5.7
# Japan                      4.5           4.3  ...       6.70        8.4
# Hong Kong, China           2.8           3.3  ...        NaN        NaN
#
# ...

# %%
#Since Hong Kong has no records in male_df, mena value is inserted
mean_hongkong = (f_low_table['mean_general'].iloc[2] + f_low_table['mean_female'].iloc[2])/2
m_low_table['mean_male'].iloc[2] = mean_hongkong

# %%
#displaying the mean value
mean_hongkong
# Out:
# 8.097111153223779

# %%
#Plotting the country with least unemployment rate
plt.figure(figsize=(8,5))
plt.plot(f_low_table.mean_general,marker='D',label="Overall unemployed rate")
plt.plot(f_low_table.mean_female,marker='D',label="Female unemployed rate")
plt.plot(m_low_table.mean_male,marker='D',label="Male unemployed rate")
plt.title('Countries with least unemployment rate from 1980-2005 (in %)')
plt.legend()
plt.savefig('Least unemployment rate.png',dpi=300)
